# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
import os

# %%
accident_df_2019_enc = pd.read_csv('2019_east_north_central_division.csv')
accident_df_2019_enc.head()
# Out:
#    Severity  Start_Lat  Start_Lng      Street          City   County State  \
# 0         2  43.001680 -83.699140      I-69 W         Flint  Genesee    MI
# 1         2  39.882420 -86.221992   W 71st St  Indianapolis   Marion    IN
# 2         2  41.884491 -87.627922  N State St       Chicago     Cook    IL
# 3         3  39.748440 -86.264847     I-465 S  Indianapolis   Marion    IN
# 4         2  42.910770 -83.533691     Gale Rd      Goodrich  Genesee    MI
#
#    Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# 0            70.0           70.0         87.0         29.11            10.0
# 1            50.0           50.0         74.0         29.22            10.0
# 2            37.0           27.0         96.0         29.79             9.0
# 3            50.0           50.0         59.0         29.07            10.0
# 4            11.0            0.0         77.0         29.44            10.0
#
#    Wind_Speed(mph)  Precipitation(in)
# ...

# %%
#driver_stat = pd.read_csv('total_driver_age_state.csv')
#driver_stats = driver_stat.rename(columns={"STATE":"St","Postal Code":"State"})
#driver_stats['State'] = driver_stats['State'].astype(str)
#driver_stats.head()

# %%
#driver_stats.dtypes

# %%
#accident_df_2019_enc.dtypes

# %%
#accident_data_w_demo = accident_df_2019_enc.join(driver_stats,on='State')
